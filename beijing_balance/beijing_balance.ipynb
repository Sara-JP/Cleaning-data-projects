# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مجموعه‌داده نامتوازن
# </font>
# </h1>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# خواندن مجموعه‌داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# ابتدا نیاز است فایل مجموعه‌داده‌ی بدون مقادیر گم‌شده (<code>beijing_no_missing.csv</code>) را بخوانیم.
# </p>

# %%
import pandas as pd
# reading the dataset
df = pd.read_csv('beijing_no_missing.csv', encoding='gbk', low_memory=False)

# %%
df.head()
# Out:
#                                                  url            id  \
# 0  https://bj.lianjia.com/chengjiao/101084782030....  101084782030
# 1  https://bj.lianjia.com/chengjiao/101086012217....  101086012217
# 2  https://bj.lianjia.com/chengjiao/101086041636....  101086041636
# 3  https://bj.lianjia.com/chengjiao/101086406841....  101086406841
# 4  https://bj.lianjia.com/chengjiao/101086920653....  101086920653
#
#           Lng        Lat            Cid   tradeTime     DOM  followers  \
# 0  116.475489  40.019520  1111027376244  2016-08-09  1464.0        106
# 1  116.453917  39.881534  1111027381879  2016-07-28   903.0        126
# 2  116.561978  39.877145  1111040862969  2016-12-11  1271.0         48
# 3  116.438010  40.076114  1111043185817  2016-09-30   965.0        138
# 4  116.428392  39.886229  1111027381174  2016-08-28   927.0        286
#
#    totalPrice  price  ...         buildingStructure  ladderRatio  \
# 0       415.0  31680  ...  steel-concrete composite        0.217
# 1       575.0  43436  ...  steel-concrete composite        0.667
# 2      1030.0  52021  ...  steel-concrete composite        0.500
# 3       297.5  22202  ...  steel-concrete composite        0.273
# 4       392.0  48396  ...                     mixed        0.333
#
#        elevator  fiveYearsProperty      subway district communityAverage  \
# 0  has elevator                 no  has subway        7          56021.0
# 1  has elevator                yes   no subway        7          71539.0
# 2  has elevator                 no   no subway        7          48160.0
# 3  has elevator                 no   no subway        6          51238.0
# 4   no elevator                yes  has subway        1          62588.0
#
#    price_category buildingStrucure_ismissing buildingType_ismissing
# 0         average                      False                  False
# 1         average                      False                  False
# 2         average                      False                  False
# 3           cheap                      False                  False
# 4         average                      False                  False
#
# [5 rows x 29 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# بررسی توازن
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# با استفاده از تابع <code>value_counts‍</code> کتابخانه‌ی پانداز، نسبت هر کلاس را مشاهده خواهیم کرد:
# </font>
# </p>

# %%
df['price_category'].value_counts(normalize=True)
# Out:
# average           0.633711
# cheap             0.179585
# expensive         0.116514
# very expensive    0.070190
# Name: price_category, dtype: float64

# %%
df['price_category'].value_counts()
# Out:
# average           202039
# cheap              57255
# expensive          37147
# very expensive     22378
# Name: price_category, dtype: int64

# %% [markdown]
# <h2 dir="rtl" align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# متوازن‌سازی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     به کمک تکنیک‌هایی که در این درسنامه مطرح شد می‌توانیم نمونه‌های دسته‌های اقلیت را افزایش یا نمونه‌های دسته‌ی اکثریت را کاهش دهیم. با این حال، بهتر است که از روش ترکیبی استفاده کنیم. ابتدا نمونه‌های دسته‌های <code>expensive</code> و <code>very expensive</code> را افزایش داده، سپس نمونه‌های دسته‌ی <code>average</code> را کاهش می‌دهیم.
# </font>
# </p>

# %%
X = df.drop(columns=['price_category'])
y = df['price_category']
X
# Out:
#                                                       url            id  \
# 0       https://bj.lianjia.com/chengjiao/101084782030....  101084782030
# 1       https://bj.lianjia.com/chengjiao/101086012217....  101086012217
# 2       https://bj.lianjia.com/chengjiao/101086041636....  101086041636
# 3       https://bj.lianjia.com/chengjiao/101086406841....  101086406841
# 4       https://bj.lianjia.com/chengjiao/101086920653....  101086920653
# ...                                                   ...           ...
# 318814  https://bj.lianjia.com/chengjiao/BJYZ92311192....  BJYZ92311192
# 318815  https://bj.lianjia.com/chengjiao/BJYZ92320171....  BJYZ92320171
# 318816  https://bj.lianjia.com/chengjiao/BJYZ92324217....  BJYZ92324217
# 318817  https://bj.lianjia.com/chengjiao/BJYZ92333313....  BJYZ92333313
# 318818  https://bj.lianjia.com/chengjiao/BJYZ92363553....  BJYZ92363553
#
#                Lng        Lat            Cid   tradeTime     DOM  followers  \
# 0       116.475489  40.019520  1111027376244  2016-08-09  1464.0        106
# 1       116.453917  39.881534  1111027381879  2016-07-28   903.0        126
# 2       116.561978  39.877145  1111040862969  2016-12-11  1271.0         48
# 3       116.438010  40.076114  1111043185817  2016-09-30   965.0        138
# 4       116.428392  39.886229  1111027381174  2016-08-28   927.0        286
# ...            ...        ...            ...         ...     ...        ...
# 318814  116.546899  39.755236  1111027377053  2016-06-10     1.0          8
# 318815  116.497474  39.810115  1111027377957  2016-06-10     1.0          1
# 318816  116.497256  39.804081  1111027380056  2016-06-05     1.0          2
# 318817  116.501794  39.799347  1111027377054  2016-06-12    10.0          4
# 318818  116.497474  39.810115  1111027377957  2016-06-11     1.0          0
#
#         totalPrice  price  ...  renovationCondition         buildingStructure  \
# 0            415.0  31680  ...           Simplicity  steel-concrete composite
# 1            575.0  43436  ...            hardcover  steel-concrete composite
# 2           1030.0  52021  ...           Simplicity  steel-concrete composite
# 3            297.5  22202  ...                other  steel-concrete composite
# 4            392.0  48396  ...                rough                     mixed
# ...            ...    ...  ...                  ...                       ...
# 318814       350.0  20580  ...                other  steel-concrete composite
# 318815       108.8  31006  ...                other  steel-concrete composite
# 318816       359.0  35138  ...           Simplicity  steel-concrete composite
# 318817       720.0  40373  ...            hardcover                     mixed
# 318818       450.0  48675  ...            hardcover  steel-concrete composite
#
#         ladderRatio      elevator  fiveYearsProperty      subway district  \
# 0             0.217  has elevator                 no  has subway        7
# 1             0.667  has elevator                yes   no subway        7
# 2             0.500  has elevator                 no   no subway        7
# 3             0.273  has elevator                 no   no subway        6
# 4             0.333   no elevator                yes  has subway        1
# ...             ...           ...                ...         ...      ...
# 318814        0.333   no elevator                yes   no subway        3
# 318815        0.222  has elevator                 no  has subway        3
# 318816        0.500  has elevator                yes   no subway        3
# 318817        0.500   no elevator                yes   no subway        3
# 318818        1.000  has elevator                 no  has subway        3
#
#         communityAverage buildingStrucure_ismissing buildingType_ismissing
# 0                56021.0                      False                  False
# 1                71539.0                      False                  False
# 2                48160.0                      False                  False
# 3                51238.0                      False                  False
# 4                62588.0                      False                  False
# ...                  ...                        ...                    ...
# 318814           36545.0                      False                  False
# 318815           54282.0                      False                  False
# 318816           46927.0                      False                  False
# 318817           54842.0                      False                  False
# 318818           54282.0                      False                  False
#
# [318819 rows x 28 columns]

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(sampling_strategy={'expensive': 57000, 'very expensive': 57000})
X_resampled, y_resampled = ros.fit_resample(X, y)

# %%
y_resampled.value_counts()
# Out:
# average           202039
# cheap              57255
# very expensive     57000
# expensive          57000
# Name: price_category, dtype: int64

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(sampling_strategy={'average': 58000})
X_resampled, y_resampled = rus.fit_resample(X_resampled, y_resampled)

# %%
y_resampled.value_counts()
# Out:
# average           58000
# cheap             57255
# expensive         57000
# very expensive    57000
# Name: price_category, dtype: int64

# %%
X_resampled
# Out:
#                                                       url            id  \
# 0       https://bj.lianjia.com/chengjiao/BJFT89252838....  BJFT89252838
# 1       https://bj.lianjia.com/chengjiao/101101041023....  101101041023
# 2       https://bj.lianjia.com/chengjiao/BJXC84491868....  BJXC84491868
# 3       https://bj.lianjia.com/chengjiao/BJCY89838807....  BJCY89838807
# 4       https://bj.lianjia.com/chengjiao/BJCP86569478....  BJCP86569478
# ...                                                   ...           ...
# 229250  https://bj.lianjia.com/chengjiao/101091917255....  101091917255
# 229251  https://bj.lianjia.com/chengjiao/101100188485....  101100188485
# 229252  https://bj.lianjia.com/chengjiao/101101440741....  101101440741
# 229253  https://bj.lianjia.com/chengjiao/BJXC90935582....  BJXC90935582
# 229254  https://bj.lianjia.com/chengjiao/101101736676....  101101736676
#
#                Lng        Lat            Cid   tradeTime    DOM  followers  \
# 0       116.407622  39.850900  1111027378372  2015-06-14    1.0          4
# 1       116.397839  39.868935  1111027381044  2017-01-17   12.0          0
# 2       116.343245  39.900529  1111027378998  2012-05-04    1.0          0
# 3       116.518854  39.939588  1111027374656  2015-10-27    1.0         16
# 4       116.346630  40.096608  1111027378138  2014-03-04    1.0          3
# ...            ...        ...            ...         ...    ...        ...
# 229250  116.362988  39.919549  1111027374403  2016-07-11   99.0         28
# 229251  116.369634  39.949548  1111027382109  2016-06-27   12.0          0
# 229252  116.480923  39.900942  1111027379643  2017-11-13  221.0        117
# 229253  116.384103  39.972885  1111027378248  2015-11-27    1.0          1
# 229254  116.389264  39.886874  1111027376481  2017-07-27   33.0         57
#
#         totalPrice   price  ...  renovationCondition  \
# 0            157.5   27574  ...                rough
# 1            340.0   54999  ...                other
# 2            135.0   44599  ...                other
# 3            420.0   31077  ...                other
# 4            580.0   35453  ...                other
# ...            ...     ...  ...                  ...
# 229250       761.0   93720  ...            hardcover
# 229251       552.0   85054  ...           Simplicity
# 229252       510.0   86868  ...            hardcover
# 229253       408.0   94445  ...           Simplicity
# 229254       530.0  101455  ...                rough
#
#                buildingStructure  ladderRatio      elevator  \
# 0                       concrete        0.333   no elevator
# 1                          mixed        0.500   no elevator
# 2       steel-concrete composite        0.120  has elevator
# 3       steel-concrete composite        0.667  has elevator
# 4                          mixed        0.500  has elevator
# ...                          ...          ...           ...
# 229250                     mixed        0.250  has elevator
# 229251                     mixed        0.500   no elevator
# 229252  steel-concrete composite        0.333  has elevator
# 229253                     mixed        0.400  has elevator
# 229254  steel-concrete composite        0.214  has elevator
#
#         fiveYearsProperty      subway district  communityAverage  \
# 0                     yes  has subway        2           49765.0
# 1                     yes  has subway        2           55055.0
# 2                      no  has subway       10           92360.0
# 3                     yes   no subway        7           58092.0
# 4                     yes  has subway        6           48298.0
# ...                   ...         ...      ...               ...
# 229250                yes  has subway       10          109704.0
# 229251                 no  has subway       10           90814.0
# 229252                yes  has subway        7           79235.0
# 229253                yes   no subway       10          129541.0
# 229254                 no  has subway       10           91507.0
#
#        buildingStrucure_ismissing buildingType_ismissing
# 0                           False                  False
# 1                           False                  False
# 2                           False                  False
# 3                           False                  False
# 4                           False                  False
# ...                           ...                    ...
# 229250                      False                  False
# 229251                      False                  False
# 229252                      False                  False
# 229253                      False                  False
# 229254                      False                  False
#
# [229255 rows x 28 columns]

# %%
df
# Out:
#                                                       url            id  \
# 0       https://bj.lianjia.com/chengjiao/101084782030....  101084782030
# 1       https://bj.lianjia.com/chengjiao/101086012217....  101086012217
# 2       https://bj.lianjia.com/chengjiao/101086041636....  101086041636
# 3       https://bj.lianjia.com/chengjiao/101086406841....  101086406841
# 4       https://bj.lianjia.com/chengjiao/101086920653....  101086920653
# ...                                                   ...           ...
# 318814  https://bj.lianjia.com/chengjiao/BJYZ92311192....  BJYZ92311192
# 318815  https://bj.lianjia.com/chengjiao/BJYZ92320171....  BJYZ92320171
# 318816  https://bj.lianjia.com/chengjiao/BJYZ92324217....  BJYZ92324217
# 318817  https://bj.lianjia.com/chengjiao/BJYZ92333313....  BJYZ92333313
# 318818  https://bj.lianjia.com/chengjiao/BJYZ92363553....  BJYZ92363553
#
#                Lng        Lat            Cid   tradeTime     DOM  followers  \
# 0       116.475489  40.019520  1111027376244  2016-08-09  1464.0        106
# 1       116.453917  39.881534  1111027381879  2016-07-28   903.0        126
# 2       116.561978  39.877145  1111040862969  2016-12-11  1271.0         48
# 3       116.438010  40.076114  1111043185817  2016-09-30   965.0        138
# 4       116.428392  39.886229  1111027381174  2016-08-28   927.0        286
# ...            ...        ...            ...         ...     ...        ...
# 318814  116.546899  39.755236  1111027377053  2016-06-10     1.0          8
# 318815  116.497474  39.810115  1111027377957  2016-06-10     1.0          1
# 318816  116.497256  39.804081  1111027380056  2016-06-05     1.0          2
# 318817  116.501794  39.799347  1111027377054  2016-06-12    10.0          4
# 318818  116.497474  39.810115  1111027377957  2016-06-11     1.0          0
#
#         totalPrice  price  ...         buildingStructure  ladderRatio  \
# 0            415.0  31680  ...  steel-concrete composite        0.217
# 1            575.0  43436  ...  steel-concrete composite        0.667
# 2           1030.0  52021  ...  steel-concrete composite        0.500
# 3            297.5  22202  ...  steel-concrete composite        0.273
# 4            392.0  48396  ...                     mixed        0.333
# ...            ...    ...  ...                       ...          ...
# 318814       350.0  20580  ...  steel-concrete composite        0.333
# 318815       108.8  31006  ...  steel-concrete composite        0.222
# 318816       359.0  35138  ...  steel-concrete composite        0.500
# 318817       720.0  40373  ...                     mixed        0.500
# 318818       450.0  48675  ...  steel-concrete composite        1.000
#
#             elevator  fiveYearsProperty      subway district communityAverage  \
# 0       has elevator                 no  has subway        7          56021.0
# 1       has elevator                yes   no subway        7          71539.0
# 2       has elevator                 no   no subway        7          48160.0
# 3       has elevator                 no   no subway        6          51238.0
# 4        no elevator                yes  has subway        1          62588.0
# ...              ...                ...         ...      ...              ...
# 318814   no elevator                yes   no subway        3          36545.0
# 318815  has elevator                 no  has subway        3          54282.0
# 318816  has elevator                yes   no subway        3          46927.0
# 318817   no elevator                yes   no subway        3          54842.0
# 318818  has elevator                 no  has subway        3          54282.0
#
#         price_category buildingStrucure_ismissing buildingType_ismissing
# 0              average                      False                  False
# 1              average                      False                  False
# 2              average                      False                  False
# 3                cheap                      False                  False
# 4              average                      False                  False
# ...                ...                        ...                    ...
# 318814           cheap                      False                  False
# 318815         average                      False                  False
# 318816         average                      False                  False
# 318817         average                      False                  False
# 318818         average                      False                  False
#
# [318819 rows x 29 columns]
